# %% [markdown]
# <a href="https://colab.research.google.com/github/parthasarathi074/-Movie-Recommendations-and-User-Preferences-Using-Big-Data/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    "User_ID": ["U001","U002","U003","U004","U005","U006","U007","U008"],
    "Age": [25,32,19,28,40,22,35,27],
    "Gender": ["M","F","M","F","M","F","M","F"],
    "Location": ["Hyderabad","Bangalore","Delhi","Chennai","Mumbai","Pune","Kolkata","Hyderabad"],
    "Movie_ID": ["M101","M102","M103","M104","M105","M106","M107","M108"],
    "Title": ["Inception","The Notebook","Avengers: Endgame","Parasite","The Godfather","Frozen","Interstellar","Joker"],
    "Genre": ["Sci-Fi, Thriller","Romance, Drama","Action, Sci-Fi","Thriller, Drama","Crime, Drama","Animation, Kids","Sci-Fi, Drama","Drama, Thriller"],
    "Rating (1–5)": [5,4,5,5,5,3,4,4],
    "Watched (Y/N)": ["Y","Y","Y","Y","Y","Y","Y","Y"],
    "Preferred_Device": ["Mobile","Smart TV","Laptop","Smart TV","Tablet","Mobile","Smart TV","Laptop"]
}

df = pd.DataFrame(data)
print(df)
# Out:
#   User_ID  Age Gender   Location Movie_ID              Title  \
# 0    U001   25      M  Hyderabad     M101          Inception
# 1    U002   32      F  Bangalore     M102       The Notebook
# 2    U003   19      M      Delhi     M103  Avengers: Endgame
# 3    U004   28      F    Chennai     M104           Parasite
# 4    U005   40      M     Mumbai     M105      The Godfather
# 5    U006   22      F       Pune     M106             Frozen
# 6    U007   35      M    Kolkata     M107       Interstellar
# 7    U008   27      F  Hyderabad     M108              Joker
#
#               Genre  Rating (1–5) Watched (Y/N) Preferred_Device
# 0  Sci-Fi, Thriller             5             Y           Mobile
# 1    Romance, Drama             4             Y         Smart TV
# 2    Action, Sci-Fi             5             Y           Laptop
# 3   Thriller, Drama             5             Y         Smart TV
# 4      Crime, Drama             5             Y           Tablet
# ...

# %%
import pandas as pd

# Extended dataset with 20 rows
data = {
    "User_ID": [f"U{i:03d}" for i in range(1, 21)],
    "Age": [25,32,19,28,40,22,35,27,30,21,26,33,24,29,38,20,31,36,23,28],
    "Gender": ["M","F","M","F","M","F","M","F","M","F","M","F","M","F","M","F","M","F","M","F"],
    "Location": [
        "Hyderabad","Bangalore","Delhi","Chennai","Mumbai","Pune","Kolkata","Hyderabad",
        "Delhi","Chennai","Mumbai","Pune","Kolkata","Hyderabad","Bangalore","Delhi",
        "Chennai","Mumbai","Pune","Kolkata"
    ],
    "Movie_ID": [f"M{i:03d}" for i in range(101, 121)],
    "Title": [
        "Inception","The Notebook","Avengers: Endgame","Parasite","The Godfather",
        "Frozen","Interstellar","Joker","Titanic","Shutter Island","Toy Story",
        "Black Panther","La La Land","The Dark Knight","Soul","Doctor Strange",
        "Coco","Fight Club","Zootopia","Dune"
    ],
    "Genre": [
        "Sci-Fi, Thriller","Romance, Drama","Action, Sci-Fi","Thriller, Drama","Crime, Drama",
        "Animation, Kids","Sci-Fi, Drama","Drama, Thriller","Romance, Drama","Thriller, Mystery",
        "Animation, Family","Action, Adventure","Romance, Musical","Action, Thriller","Animation, Fantasy",
        "Action, Sci-Fi","Animation, Family","Drama, Thriller","Animation, Comedy","Sci-Fi, Adventure"
    ],
    "Rating (1–5)": [5,4,5,5,5,3,4,4,5,4,4,5,4,5,3,4,5,5,4,5],
    "Preferred_Device": [
        "Mobile","Smart TV","Laptop","Smart TV","Tablet","Mobile","Smart TV","Laptop",
        "Laptop","Smart TV","Tablet","Mobile","Smart TV","Laptop","Mobile","Smart TV",
        "Tablet","Laptop","Mobile","Smart TV"
    ],
    "Release_Year": [
        2010,2004,2019,2019,1972,2013,2014,2019,1997,2010,1995,2018,2016,2008,2020,2016,2017,1999,2016,2021
    ],
    "Duration (min)": [
        148,123,181,132,175,102,169,122,195,138,81,134,128,152,100,115,105,139,108,155
    ],
    "Platform": [
        "Netflix","Prime","Disney+","Netflix","Prime","Disney+","Netflix","Prime",
        "Prime","Netflix","Disney+","Disney+","Netflix","Prime","Disney+","Disney+",
        "Netflix","Prime","Disney+","Netflix"
    ],
    "Watch_Frequency (per month)": [4,2,6,3,1,5,2,3,4,2,3,5,2,4,1,3,4,2,3,5]
}

# Create DataFrame
df = pd.DataFrame(data)

# Display the dataset
print(df)

# Optional: quick summary
print("\n--- Dataset Info ---")
print(df.info())

print("\n--- Summary Statistics ---")
print(df.describe(include='all'))
# Out:
#    User_ID  Age Gender   Location Movie_ID              Title  \
# 0     U001   25      M  Hyderabad     M101          Inception
# 1     U002   32      F  Bangalore     M102       The Notebook
# 2     U003   19      M      Delhi     M103  Avengers: Endgame
# 3     U004   28      F    Chennai     M104           Parasite
# 4     U005   40      M     Mumbai     M105      The Godfather
# 5     U006   22      F       Pune     M106             Frozen
# 6     U007   35      M    Kolkata     M107       Interstellar
# 7     U008   27      F  Hyderabad     M108              Joker
# 8     U009   30      M      Delhi     M109            Titanic
# 9     U010   21      F    Chennai     M110     Shutter Island
# 10    U011   26      M     Mumbai     M111          Toy Story
# 11    U012   33      F       Pune     M112      Black Panther
# 12    U013   24      M    Kolkata     M113         La La Land
# 13    U014   29      F  Hyderabad     M114    The Dark Knight
# ...
